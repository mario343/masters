# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.calibration import CalibratedClassifierCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler


from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
train = np.load("./data/processed/TRAIN_30.npz", allow_pickle=True)
X_train = train["X"][::40]
y_train = train["y"][::40]

full = np.load("./data/processed/FULL_30.npz", allow_pickle=True)
X_full  = full["X"][::100]
Delta_full = full["Delta"][::100]

# %%
cols_20 = np.setdiff1d(
    np.arange(30),
    [2,3,5,7,12,18,21,24,27,28]
)
cols_12 = [0,2,4,5,6,11,12,15,17,23,24,29]

# %%
feature_sets = {
    "30": np.arange(30),
    "20": cols_20,
    "12": cols_12,
}

# %%
summary_rows = []
mean_rows = []
chi_rows = []

# %%
def build_model(base_model, calibrated=False):
    pipe = Pipeline([
        # ("scaler", StandardScaler()),
        ("clf", base_model)
    ])
    if not calibrated:
        return pipe

    return CalibratedClassifierCV(pipe)

# %%
def run_supervised_pipeline(model, X_train, y_train, X_full):
    model.fit(X_train, y_train)
    train_score = model.score(X_train, y_train)

    if hasattr(model, "predict_proba"):
        P_B = model.predict_proba(X_full)[:, 1]
    else:
        scores = model.decision_function(X_full)
        P_B = 1.0 / (1.0 + np.exp(-scores))

    return train_score, P_B

# %%
def stat_mean(x):
    return np.mean(x)



def stat_susceptibility(x):
    mu = np.mean(x)

    if abs(mu) < 1e-12:
        return 0.0

    return np.var(x, ddof=1) #######/ mu

    
    # def stat_susceptibility(x):
#     # Mathematica: Variance[...] / Mean[...] where Variance uses ddof=1
#     return np.var(x, ddof=1) / np.mean(x)

# %%
def block_jackknife(data, stat_func, B):
    """
    Block jackknife with B blocks.
      - truncate data to m*B elements
      - reshape into B blocks of size m
      - compute full estimator EX on truncated data
      - leave one block out at a time, compute stat on remaining B-1 blocks
      - bias = (B-1) * (mean(dats) - EX)          [jack.pdf eq 3.2.1]
      - theta_jack = EX - bias                      [bias-corrected estimate]
      - var = Variance(dats) * (B-1)^2 / B         [Mathematica Variance = ddof=1]
      - se = sqrt(var)

    Returns: (theta_hat, theta_jack, se) for this specific B,
             or None if block size < 1.
    """
    n = len(data)
    m = n // B  # block size (integer division, matches Mathematica Quotient)

    if m < 1:
        return None

    # Truncate to m*B  (matches: data[[1 ;; Quotient[len,B]*B]])
    data = data[:m * B]

    # Reshape into B blocks  (matches: Table[data[[m*i+1 ;; m*(i+1)]], {i,0,B-1}])
    blocks = data.reshape(B, m)

    # Full estimator on truncated data  (matches: EX = stat_func(data))
    theta_hat = stat_func(data)

    # Leave-one-block-out replicates
    # Matches: rands = Table[DeleteCases[Range[B], i], {i, B}]
    #          dats  = Table[stat(Flatten[blocks[rands[i]]]), {i, B}]
    dats = np.array([
        stat_func(np.concatenate([blocks[:i], blocks[i+1:]]).ravel())
        for i in range(B)
    ])

    # Bias: (B-1) * (mean(dats) - EX)  [jack.pdf 3.2.1, Mathematica bias line]
    bias = (B - 1) * (np.mean(dats) - theta_hat)

    # Bias-corrected estimator: EXUn = EX - bias
    theta_jack = theta_hat - bias

    # Variance of replications using ddof=1  (Mathematica Variance = sample variance)
    # var = Variance[dats] * (B-1)^2 / B
    var = np.var(dats, ddof=1) * (B - 1)**2 / B
    se = np.sqrt(var)

    return theta_hat, theta_jack, se

# %%
# =============================================================================
# JACKKNIFE OVER Delta — returns FULL TABLE for every B, matching Mathematica output
# =============================================================================

def jackknife_over_Delta(P_B, Delta, stat_func, B_range=range(2, 101)):
    """
    For each unique Delta value, run block_jackknife for every B in B_range.

    Returns a dict:  {k: DataFrame with columns [B, theta_hat, theta_jack, se]}

    This matches the Mathematica Table[..., {ildanych, 2, 100, 1}] output exactly.
    You can then inspect SE vs B plots to find the plateau, rather than
    artificially picking the maximum SE.
    """
    df_input = pd.DataFrame({"Delta": Delta, "P_B": P_B})
    results = {}

    for d, group in df_input.groupby("Delta"):
        data = group["P_B"].values
        # print(k, len(data))

        if len(data) < 2:
            continue

        rows = []
        for B in B_range:
            out = block_jackknife(data, stat_func, B)
            if out is None:
                continue
            theta_hat, theta_jack, se = out
            rows.append({
                "B":          B,
                "theta_hat":  theta_hat,   # EX  in Mathematica
                "theta_jack": theta_jack,  # EXUn in Mathematica
                "se":         se,          # Smse in Mathematica
            })

        results[d] = pd.DataFrame(rows)
    return results

# %%
def summarise_jackknife(results_dict):

    Delta_vals, theta_arr, se_arr = [], [], []

    for d in sorted(results_dict.keys()):
        df = results_dict[d]

        if df.empty:
            continue

        df_valid = df.dropna(subset=["se"])

        if df_valid.empty:
            print(f"All SE are NaN for Delta={d}")
            continue

        row = df_valid.loc[df_valid["se"].idxmax()]

        Delta_vals.append(d)
        theta_arr.append(row["theta_jack"])
        se_arr.append(row["se"])

    return (
        np.array(Delta_vals),
        np.array(theta_arr),
        np.array(se_arr),
    )



def plot_se_vs_B(results_dict, stat_label, target_Deltas=None, ncols=5):
    """
    Plot SE vs B for each K value.
    Use this to verify that the SE has plateaued before trusting the summary.
    All K values are shown, arranged in a grid with ncols columns.
    """
    ds = sorted(results_dict.keys())
    if target_Deltas is not None:
        ds = [k for k in ds if k in target_Deltas]

    n = len(ds)
    if n == 0:
        return

    nrows = int(np.ceil(n / ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 3.5 * nrows), squeeze=False)

    for idx, k in enumerate(ds):
        row, col = divmod(idx, ncols)
        ax = axes[row][col]
        df = results_dict[k]
        ax.plot(df["B"], df["se"], lw=1.5)
        ax.set_title(f"Delta = {k:.3f}")
        ax.set_xlabel("B (number of blocks)")
        ax.set_ylabel(f"SE of {stat_label}")
        ax.grid(True, alpha=0.3)

    # Hide any leftover empty subplots
    for idx in range(n, nrows * ncols):
        row, col = divmod(idx, ncols)
        axes[row][col].set_visible(False)

    fig.suptitle(f"SE vs B — {stat_label} (should plateau)", y=1.02)
    plt.tight_layout()

# %%
from scipy.interpolate import interp1d
from scipy.optimize import brentq


def find_delta_crit(D, mean, mean_err):
    """
    Find delta where mean(delta)=0.5
    and estimate uncertainty via error propagation.
    """

    idx_close = np.argmin(np.abs(mean-0.5))
    d_close = D[idx_close]
    
    f = interp1d(
        D,
        mean - 0.5,
        kind="linear",
        bounds_error=False
    )

    idx = np.where(
        (mean[:-1] - 0.5) *
        (mean[1:]  - 0.5) <= 0
    )[0]

    if len(idx) == 0:
        return np.nan, np.nan, np.nan

    i = idx[0]

    dcrit = brentq(
        lambda x: f(x),
        D[i],
        D[i + 1]
    )

    slope = (
        mean[i + 1] - mean[i]
    ) / (
        D[i + 1] - D[i]
    )

    sigma_p = np.interp(
        dcrit,
        [D[i], D[i + 1]],
        [mean_err[i], mean_err[i + 1]]
    )
    if abs(slope) < 1e-12:
        return dcrit, np.nan, d_close
    
    sigma_d = sigma_p / abs(slope)

    return dcrit, sigma_d, d_close

# %%
def timed(func, *args, **kwargs):
    t0 = time.perf_counter()
    result = func(*args, **kwargs)
    elapsed = time.perf_counter() - t0
    return result, elapsed

# %%
# =============================================================================
# MAIN
# =============================================================================

neighbors = list(range(1, 52, 2)) + [61, 81, 101, 151, 201]

algorithms = [
    "auto",
    "kd_tree",
    "ball_tree",
    "brute",
]

models = {}

for algorithm in algorithms:
    for k in neighbors:
        name = f"KNN | {algorithm} | k={k}"

        models[name] = KNeighborsClassifier(
            n_neighbors=k,
            algorithm=algorithm,
            n_jobs=-1,
        )

curves = {}

for feature_name, cols in feature_sets.items():

    X_train_fs = X_train[:, cols]
    X_full_fs  = X_full[:, cols]

    curves[feature_name] = {}

    print(
        f"\n{'='*70}"
        f"\nFEATURE SET: {feature_name}"
        f" ({len(cols)} features)"
        f"\n{'='*70}"
    )

    for name, base_model in models.items():

        print(f"\n{'='*50}\nModel: {name}\n{'='*50}")
        curves[feature_name][name] = {}

        for calibrated in [False]:

            label = "calibrated" if calibrated else "uncalibrated"

            model = build_model(base_model, calibrated=calibrated)

            (train_score, P_B), model_time = timed(
                run_supervised_pipeline,
                model,
                X_train_fs,
                y_train,
                X_full_fs,
            )

            mean_results, mean_jack_time = timed(
                jackknife_over_Delta,
                P_B,
                Delta_full,
                stat_mean,
            )

            chi_results, chi_jack_time = timed(
                jackknife_over_Delta,
                P_B,
                Delta_full,
                stat_susceptibility,
            )

            print(f"  Delta values found: {len(mean_results)}")

            (D_mean, mean_jack, mean_se), summary_mean_time = timed(
                summarise_jackknife,
                mean_results,
            )

            (D_chi, chi_jack, chi_se), summary_chi_time = timed(
                summarise_jackknife,
                chi_results,
            )

            (dcrit, dcrit_err, d_close), time_delta_crit = timed(
                find_delta_crit,
                D_mean,
                mean_jack,
                mean_se,
            )

            total_time = (
                model_time
                + mean_jack_time
                + chi_jack_time
                + summary_mean_time
                + summary_chi_time
                + time_delta_crit
            )

            print(
                f"{label:12s} | "
                f"train_acc={train_score:.4f} | "
                f"total_time={total_time:.3f}"
            )

            curves[feature_name][name][label] = {
                "train_acc": train_score,
                "runtime_sec": total_time,
                "D": D_mean,
                "mean": mean_jack,
                "mean_se": mean_se,
                "chi": chi_jack,
                "chi_se": chi_se,
                "Delta_crit": dcrit,
                "Delta_crit_err": dcrit_err,
                "Delta_close": d_close,
                "_mean_results": mean_results,
                "_chi_results": chi_results,
            }

            summary_rows.append({
                "feature_set": feature_name,
                "n_features": len(cols),

                "model": "KNN",
                "algorithm": base_model.algorithm,
                "n_neighbors": base_model.n_neighbors,

                "calibration": label,
                "train_acc": train_score,

                "Delta_crit": dcrit,
                "Delta_crit_err": dcrit_err,
                "Delta_close": d_close,
                "N_Delta": len(D_mean),

                "runtime_model": round(model_time, 3),
                "runtime_jackknife_mean": round(mean_jack_time, 3),
                "runtime_jackknife_chi": round(chi_jack_time, 3),
                "summary_mean_time": round(summary_mean_time, 4),
                "summary_chi_time": round(summary_chi_time, 4),
                "runtime_delta_crit": round(time_delta_crit, 5),
                "runtime_total": round(total_time, 3),
            })

            for d, m, err in zip(D_mean, mean_jack, mean_se):
                mean_rows.append({
                    "feature_set": feature_name,
                    "n_features": len(cols),
                    "model": "KNN",
                    "algorithm": base_model.algorithm,
                    "n_neighbors": base_model.n_neighbors,
                    "calibration": label,
                    "Delta": d,
                    "mean": m,
                    "mean_err": err,
                })

            for d, c, err in zip(D_chi, chi_jack, chi_se):
                chi_rows.append({
                    "feature_set": feature_name,
                    "n_features": len(cols),
                    "model": "KNN",
                    "algorithm": base_model.algorithm,
                    "n_neighbors": base_model.n_neighbors,
                    "calibration": label,
                    "Delta": d,
                    "chi": c,
                    "chi_err": err,
                })
# Out:
# ======================================================================
# FEATURE SET: 30 (30 features)
# ======================================================================
#
# ==================================================
# Model: KNN | auto | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=5.139
#
# ==================================================
# Model: KNN | auto | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.170
#
# ==================================================
# Model: KNN | auto | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.044
#
# ==================================================
# Model: KNN | auto | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.462
#
# ==================================================
# Model: KNN | auto | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.079
#
# ==================================================
# Model: KNN | auto | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.927
#
# ==================================================
# Model: KNN | auto | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.736
#
# ==================================================
# Model: KNN | auto | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.055
#
# ==================================================
# Model: KNN | auto | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.678
#
# ==================================================
# Model: KNN | auto | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.257
#
# ==================================================
# Model: KNN | auto | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.384
#
# ==================================================
# Model: KNN | auto | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.300
#
# ==================================================
# Model: KNN | auto | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.179
#
# ==================================================
# Model: KNN | auto | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.797
#
# ==================================================
# Model: KNN | auto | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.173
#
# ==================================================
# Model: KNN | auto | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.066
#
# ==================================================
# Model: KNN | auto | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.249
#
# ==================================================
# Model: KNN | auto | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.998
#
# ==================================================
# Model: KNN | auto | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.261
#
# ==================================================
# Model: KNN | auto | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.101
#
# ==================================================
# Model: KNN | auto | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.326
#
# ==================================================
# Model: KNN | auto | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.269
#
# ==================================================
# Model: KNN | auto | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.312
#
# ==================================================
# Model: KNN | auto | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.398
#
# ==================================================
# Model: KNN | auto | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.136
#
# ==================================================
# Model: KNN | auto | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.945
#
# ==================================================
# Model: KNN | auto | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.034
#
# ==================================================
# Model: KNN | auto | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.365
#
# ==================================================
# Model: KNN | auto | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.342
#
# ==================================================
# Model: KNN | auto | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.495
#
# ==================================================
# Model: KNN | auto | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.322
#
# ==================================================
# Model: KNN | kd_tree | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.401
#
# ==================================================
# Model: KNN | kd_tree | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.696
#
# ==================================================
# Model: KNN | kd_tree | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.663
#
# ==================================================
# Model: KNN | kd_tree | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.652
#
# ==================================================
# Model: KNN | kd_tree | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.657
#
# ==================================================
# Model: KNN | kd_tree | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.722
#
# ==================================================
# Model: KNN | kd_tree | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.758
#
# ==================================================
# Model: KNN | kd_tree | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.744
#
# ==================================================
# Model: KNN | kd_tree | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.795
#
# ==================================================
# Model: KNN | kd_tree | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.748
#
# ==================================================
# Model: KNN | kd_tree | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.782
#
# ==================================================
# Model: KNN | kd_tree | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.868
#
# ==================================================
# Model: KNN | kd_tree | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.821
#
# ==================================================
# Model: KNN | kd_tree | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.772
#
# ==================================================
# Model: KNN | kd_tree | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.883
#
# ==================================================
# Model: KNN | kd_tree | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.887
#
# ==================================================
# Model: KNN | kd_tree | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.865
#
# ==================================================
# Model: KNN | kd_tree | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.715
#
# ==================================================
# Model: KNN | kd_tree | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.871
#
# ==================================================
# Model: KNN | kd_tree | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.900
#
# ==================================================
# Model: KNN | kd_tree | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.822
#
# ==================================================
# Model: KNN | kd_tree | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.906
#
# ==================================================
# Model: KNN | kd_tree | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.929
#
# ==================================================
# Model: KNN | kd_tree | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.995
#
# ==================================================
# Model: KNN | kd_tree | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.727
#
# ==================================================
# Model: KNN | kd_tree | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.853
#
# ==================================================
# Model: KNN | kd_tree | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.913
#
# ==================================================
# Model: KNN | kd_tree | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.959
#
# ==================================================
# Model: KNN | kd_tree | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.090
#
# ==================================================
# Model: KNN | kd_tree | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.230
#
# ==================================================
# Model: KNN | kd_tree | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.456
#
# ==================================================
# Model: KNN | ball_tree | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.867
#
# ==================================================
# Model: KNN | ball_tree | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.003
#
# ==================================================
# Model: KNN | ball_tree | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.938
#
# ==================================================
# Model: KNN | ball_tree | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.916
#
# ==================================================
# Model: KNN | ball_tree | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.930
#
# ==================================================
# Model: KNN | ball_tree | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.881
#
# ==================================================
# Model: KNN | ball_tree | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.840
#
# ==================================================
# Model: KNN | ball_tree | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.954
#
# ==================================================
# Model: KNN | ball_tree | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.134
#
# ==================================================
# Model: KNN | ball_tree | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.053
#
# ==================================================
# Model: KNN | ball_tree | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.147
#
# ==================================================
# Model: KNN | ball_tree | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.943
#
# ==================================================
# Model: KNN | ball_tree | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.952
#
# ==================================================
# Model: KNN | ball_tree | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.202
#
# ==================================================
# Model: KNN | ball_tree | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.260
#
# ==================================================
# Model: KNN | ball_tree | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.255
#
# ==================================================
# Model: KNN | ball_tree | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.203
#
# ==================================================
# Model: KNN | ball_tree | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.138
#
# ==================================================
# Model: KNN | ball_tree | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.285
#
# ==================================================
# Model: KNN | ball_tree | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.229
#
# ==================================================
# Model: KNN | ball_tree | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.302
#
# ==================================================
# Model: KNN | ball_tree | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.289
#
# ==================================================
# Model: KNN | ball_tree | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.852
#
# ==================================================
# Model: KNN | ball_tree | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.320
#
# ==================================================
# Model: KNN | ball_tree | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.288
#
# ==================================================
# Model: KNN | ball_tree | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.350
#
# ==================================================
# Model: KNN | ball_tree | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.396
#
# ==================================================
# Model: KNN | ball_tree | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.192
#
# ==================================================
# Model: KNN | ball_tree | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.408
#
# ==================================================
# Model: KNN | ball_tree | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.610
#
# ==================================================
# Model: KNN | ball_tree | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.577
#
# ==================================================
# Model: KNN | brute | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.217
#
# ==================================================
# Model: KNN | brute | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.075
#
# ==================================================
# Model: KNN | brute | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.970
#
# ==================================================
# Model: KNN | brute | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.076
#
# ==================================================
# Model: KNN | brute | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.461
#
# ==================================================
# Model: KNN | brute | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.106
#
# ==================================================
# Model: KNN | brute | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.341
#
# ==================================================
# Model: KNN | brute | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.888
#
# ==================================================
# Model: KNN | brute | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.244
#
# ==================================================
# Model: KNN | brute | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.918
#
# ==================================================
# Model: KNN | brute | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.970
#
# ==================================================
# Model: KNN | brute | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.868
#
# ==================================================
# Model: KNN | brute | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.842
#
# ==================================================
# Model: KNN | brute | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.263
#
# ==================================================
# Model: KNN | brute | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.246
#
# ==================================================
# Model: KNN | brute | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.248
#
# ==================================================
# Model: KNN | brute | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.325
#
# ==================================================
# Model: KNN | brute | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.140
#
# ==================================================
# Model: KNN | brute | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.106
#
# ==================================================
# Model: KNN | brute | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.231
#
# ==================================================
# Model: KNN | brute | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.991
#
# ==================================================
# Model: KNN | brute | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.044
#
# ==================================================
# Model: KNN | brute | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.081
#
# ==================================================
# Model: KNN | brute | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.107
#
# ==================================================
# Model: KNN | brute | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.946
#
# ==================================================
# Model: KNN | brute | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.222
#
# ==================================================
# Model: KNN | brute | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.857
#
# ==================================================
# Model: KNN | brute | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.368
#
# ==================================================
# Model: KNN | brute | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.332
#
# ==================================================
# Model: KNN | brute | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.399
#
# ==================================================
# Model: KNN | brute | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.446
#
# ======================================================================
# FEATURE SET: 20 (20 features)
# ======================================================================
#
# ==================================================
# Model: KNN | auto | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.154
#
# ==================================================
# Model: KNN | auto | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.721
#
# ==================================================
# Model: KNN | auto | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.881
#
# ==================================================
# Model: KNN | auto | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.808
#
# ==================================================
# Model: KNN | auto | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.807
#
# ==================================================
# Model: KNN | auto | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.973
#
# ==================================================
# Model: KNN | auto | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.875
#
# ==================================================
# Model: KNN | auto | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.014
#
# ==================================================
# Model: KNN | auto | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.014
#
# ==================================================
# Model: KNN | auto | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.739
#
# ==================================================
# Model: KNN | auto | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.057
#
# ==================================================
# Model: KNN | auto | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.834
#
# ==================================================
# Model: KNN | auto | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.864
#
# ==================================================
# Model: KNN | auto | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.297
#
# ==================================================
# Model: KNN | auto | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.951
#
# ==================================================
# Model: KNN | auto | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.856
#
# ==================================================
# Model: KNN | auto | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.993
#
# ==================================================
# Model: KNN | auto | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.855
#
# ==================================================
# Model: KNN | auto | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.978
#
# ==================================================
# Model: KNN | auto | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.985
#
# ==================================================
# Model: KNN | auto | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.264
#
# ==================================================
# Model: KNN | auto | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.218
#
# ==================================================
# Model: KNN | auto | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.739
#
# ==================================================
# Model: KNN | auto | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.282
#
# ==================================================
# Model: KNN | auto | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.246
#
# ==================================================
# Model: KNN | auto | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.788
#
# ==================================================
# Model: KNN | auto | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.045
#
# ==================================================
# Model: KNN | auto | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.077
#
# ==================================================
# Model: KNN | auto | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.328
#
# ==================================================
# Model: KNN | auto | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.369
#
# ==================================================
# Model: KNN | auto | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.362
#
# ==================================================
# Model: KNN | kd_tree | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.501
#
# ==================================================
# Model: KNN | kd_tree | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.614
#
# ==================================================
# Model: KNN | kd_tree | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.583
#
# ==================================================
# Model: KNN | kd_tree | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.667
#
# ==================================================
# Model: KNN | kd_tree | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.473
#
# ==================================================
# Model: KNN | kd_tree | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.558
#
# ==================================================
# Model: KNN | kd_tree | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.701
#
# ==================================================
# Model: KNN | kd_tree | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.727
#
# ==================================================
# Model: KNN | kd_tree | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.705
#
# ==================================================
# Model: KNN | kd_tree | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.550
#
# ==================================================
# Model: KNN | kd_tree | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.643
#
# ==================================================
# Model: KNN | kd_tree | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.565
#
# ==================================================
# Model: KNN | kd_tree | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.621
#
# ==================================================
# Model: KNN | kd_tree | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.539
#
# ==================================================
# Model: KNN | kd_tree | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.725
#
# ==================================================
# Model: KNN | kd_tree | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.598
#
# ==================================================
# Model: KNN | kd_tree | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.695
#
# ==================================================
# Model: KNN | kd_tree | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.687
#
# ==================================================
# Model: KNN | kd_tree | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.760
#
# ==================================================
# Model: KNN | kd_tree | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.842
#
# ==================================================
# Model: KNN | kd_tree | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.846
#
# ==================================================
# Model: KNN | kd_tree | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.720
#
# ==================================================
# Model: KNN | kd_tree | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.720
#
# ==================================================
# Model: KNN | kd_tree | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.731
#
# ==================================================
# Model: KNN | kd_tree | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.756
#
# ==================================================
# Model: KNN | kd_tree | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.875
#
# ==================================================
# Model: KNN | kd_tree | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.873
#
# ==================================================
# Model: KNN | kd_tree | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.839
#
# ==================================================
# Model: KNN | kd_tree | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.757
#
# ==================================================
# Model: KNN | kd_tree | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.848
#
# ==================================================
# Model: KNN | kd_tree | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.262
#
# ==================================================
# Model: KNN | ball_tree | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.662
#
# ==================================================
# Model: KNN | ball_tree | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.786
#
# ==================================================
# Model: KNN | ball_tree | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.697
#
# ==================================================
# Model: KNN | ball_tree | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.562
#
# ==================================================
# Model: KNN | ball_tree | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.849
#
# ==================================================
# Model: KNN | ball_tree | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.749
#
# ==================================================
# Model: KNN | ball_tree | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.954
#
# ==================================================
# Model: KNN | ball_tree | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.886
#
# ==================================================
# Model: KNN | ball_tree | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.683
#
# ==================================================
# Model: KNN | ball_tree | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.556
#
# ==================================================
# Model: KNN | ball_tree | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.692
#
# ==================================================
# Model: KNN | ball_tree | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.995
#
# ==================================================
# Model: KNN | ball_tree | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.814
#
# ==================================================
# Model: KNN | ball_tree | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.891
#
# ==================================================
# Model: KNN | ball_tree | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.687
#
# ==================================================
# Model: KNN | ball_tree | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.961
#
# ==================================================
# Model: KNN | ball_tree | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.981
#
# ==================================================
# Model: KNN | ball_tree | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.015
#
# ==================================================
# Model: KNN | ball_tree | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.966
#
# ==================================================
# Model: KNN | ball_tree | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.029
#
# ==================================================
# Model: KNN | ball_tree | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.740
#
# ==================================================
# Model: KNN | ball_tree | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.776
#
# ==================================================
# Model: KNN | ball_tree | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.799
#
# ==================================================
# Model: KNN | ball_tree | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.054
#
# ==================================================
# Model: KNN | ball_tree | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.793
#
# ==================================================
# Model: KNN | ball_tree | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.946
#
# ==================================================
# Model: KNN | ball_tree | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.016
#
# ==================================================
# Model: KNN | ball_tree | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.219
#
# ==================================================
# Model: KNN | ball_tree | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.285
#
# ==================================================
# Model: KNN | ball_tree | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.414
#
# ==================================================
# Model: KNN | ball_tree | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.575
#
# ==================================================
# Model: KNN | brute | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.921
#
# ==================================================
# Model: KNN | brute | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.959
#
# ==================================================
# Model: KNN | brute | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.376
#
# ==================================================
# Model: KNN | brute | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.044
#
# ==================================================
# Model: KNN | brute | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.026
#
# ==================================================
# Model: KNN | brute | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.185
#
# ==================================================
# Model: KNN | brute | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.188
#
# ==================================================
# Model: KNN | brute | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.187
#
# ==================================================
# Model: KNN | brute | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.140
#
# ==================================================
# Model: KNN | brute | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.924
#
# ==================================================
# Model: KNN | brute | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.930
#
# ==================================================
# Model: KNN | brute | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.660
#
# ==================================================
# Model: KNN | brute | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.050
#
# ==================================================
# Model: KNN | brute | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.308
#
# ...
# uncalibrated | train_acc=1.0000 | total_time=1.821
#
# ==================================================
# Model: KNN | kd_tree | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.663
#
# ==================================================
# Model: KNN | kd_tree | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.703
#
# ==================================================
# Model: KNN | kd_tree | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.744
#
# ==================================================
# Model: KNN | kd_tree | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.871
#
# ==================================================
# Model: KNN | kd_tree | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.882
#
# ==================================================
# Model: KNN | kd_tree | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.785
#
# ==================================================
# Model: KNN | kd_tree | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.772
#
# ==================================================
# Model: KNN | kd_tree | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.889
#
# ==================================================
# Model: KNN | kd_tree | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.810
#
# ==================================================
# Model: KNN | kd_tree | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.857
#
# ==================================================
# Model: KNN | kd_tree | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.870
#
# ==================================================
# Model: KNN | kd_tree | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.899
#
# ==================================================
# Model: KNN | kd_tree | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.752
#
# ==================================================
# Model: KNN | kd_tree | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.178
#
# ==================================================
# Model: KNN | kd_tree | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.159
#
# ==================================================
# Model: KNN | ball_tree | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.546
#
# ==================================================
# Model: KNN | ball_tree | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.735
#
# ==================================================
# Model: KNN | ball_tree | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.884
#
# ==================================================
# Model: KNN | ball_tree | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.530
#
# ==================================================
# Model: KNN | ball_tree | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.895
#
# ==================================================
# Model: KNN | ball_tree | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.705
#
# ==================================================
# Model: KNN | ball_tree | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.651
#
# ==================================================
# Model: KNN | ball_tree | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.915
#
# ==================================================
# Model: KNN | ball_tree | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.896
#
# ==================================================
# Model: KNN | ball_tree | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.713
#
# ==================================================
# Model: KNN | ball_tree | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.049
#
# ==================================================
# Model: KNN | ball_tree | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.826
#
# ==================================================
# Model: KNN | ball_tree | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.950
#
# ==================================================
# Model: KNN | ball_tree | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.057
#
# ==================================================
# Model: KNN | ball_tree | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.993
#
# ==================================================
# Model: KNN | ball_tree | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.928
#
# ==================================================
# Model: KNN | ball_tree | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.977
#
# ==================================================
# Model: KNN | ball_tree | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.949
#
# ==================================================
# Model: KNN | ball_tree | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.773
#
# ==================================================
# Model: KNN | ball_tree | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.914
#
# ==================================================
# Model: KNN | ball_tree | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.086
#
# ==================================================
# Model: KNN | ball_tree | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.981
#
# ==================================================
# Model: KNN | ball_tree | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.772
#
# ==================================================
# Model: KNN | ball_tree | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.775
#
# ==================================================
# Model: KNN | ball_tree | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=1.992
#
# ==================================================
# Model: KNN | ball_tree | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.190
#
# ==================================================
# Model: KNN | ball_tree | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.177
#
# ==================================================
# Model: KNN | ball_tree | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.262
#
# ==================================================
# Model: KNN | ball_tree | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.026
#
# ==================================================
# Model: KNN | ball_tree | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.383
#
# ==================================================
# Model: KNN | ball_tree | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=2.451
#
# ==================================================
# Model: KNN | brute | k=1
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.285
#
# ==================================================
# Model: KNN | brute | k=3
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.841
#
# ==================================================
# Model: KNN | brute | k=5
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.184
#
# ==================================================
# Model: KNN | brute | k=7
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.934
#
# ==================================================
# Model: KNN | brute | k=9
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.266
#
# ==================================================
# Model: KNN | brute | k=11
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.890
#
# ==================================================
# Model: KNN | brute | k=13
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.141
#
# ==================================================
# Model: KNN | brute | k=15
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.288
#
# ==================================================
# Model: KNN | brute | k=17
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.844
#
# ==================================================
# Model: KNN | brute | k=19
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.860
#
# ==================================================
# Model: KNN | brute | k=21
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.082
#
# ==================================================
# Model: KNN | brute | k=23
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.170
#
# ==================================================
# Model: KNN | brute | k=25
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.918
#
# ==================================================
# Model: KNN | brute | k=27
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.517
#
# ==================================================
# Model: KNN | brute | k=29
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.103
#
# ==================================================
# Model: KNN | brute | k=31
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.167
#
# ==================================================
# Model: KNN | brute | k=33
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.940
#
# ==================================================
# Model: KNN | brute | k=35
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=3.942
#
# ==================================================
# Model: KNN | brute | k=37
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.178
#
# ==================================================
# Model: KNN | brute | k=39
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.449
#
# ==================================================
# Model: KNN | brute | k=41
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.559
#
# ==================================================
# Model: KNN | brute | k=43
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.303
#
# ==================================================
# Model: KNN | brute | k=45
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.268
#
# ==================================================
# Model: KNN | brute | k=47
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.163
#
# ==================================================
# Model: KNN | brute | k=49
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.286
#
# ==================================================
# Model: KNN | brute | k=51
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.293
#
# ==================================================
# Model: KNN | brute | k=61
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.234
#
# ==================================================
# Model: KNN | brute | k=81
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.443
#
# ==================================================
# Model: KNN | brute | k=101
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.440
#
# ==================================================
# Model: KNN | brute | k=151
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=5.011
#
# ==================================================
# Model: KNN | brute | k=201
# ==================================================
#   Delta values found: 11
# uncalibrated | train_acc=1.0000 | total_time=4.859

# %%
import os

os.makedirs("results", exist_ok=True)

pd.DataFrame(summary_rows).to_csv(
    "results/AB_KNN_COMPARISON_summary.csv",
    index=False
)

pd.DataFrame(mean_rows).to_csv(
    "results/AB_KNN_COMPARISON_curve_mean.csv",
    index=False
)

pd.DataFrame(chi_rows).to_csv(
    "results/AB_KNN_COMPARISON_curve_chi.csv",
    index=False
)
