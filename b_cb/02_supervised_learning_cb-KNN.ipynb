# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.calibration import CalibratedClassifierCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler


from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
train = np.load("./data/processed/TRAIN_30.npz", allow_pickle=True)
X_train = train["X"][::40]
y_train = train["y"][::40]

full = np.load("./data/processed/FULL_30.npz", allow_pickle=True)
X_full  = full["X"][::100]
Delta_full = full["Delta"][::100]

# %%
cols_20 = np.setdiff1d(
    np.arange(30),
    [2,3,5,7,12,18,21,24,27,28]
)
cols_12 = [0,2,4,5,6,11,12,15,17,23,24,29]

# %%
feature_sets = {
    # "30": np.arange(30),
    "20": cols_20,
    # "12": cols_12,
}

# %%
summary_rows = []
mean_rows = []
chi_rows = []

# %%
def build_model(base_model, calibrated=False):
    pipe = Pipeline([
        # ("scaler", StandardScaler()),
        ("clf", base_model)
    ])
    if not calibrated:
        return pipe

    return CalibratedClassifierCV(pipe)

# %%
def run_supervised_pipeline(model, X_train, y_train, X_full):
    model.fit(X_train, y_train)
    train_score = model.score(X_train, y_train)

    if hasattr(model, "predict_proba"):
        P_B = model.predict_proba(X_full)[:, 1]
    else:
        scores = model.decision_function(X_full)
        P_B = 1.0 / (1.0 + np.exp(-scores))

    return train_score, P_B

# %%
def stat_mean(x):
    return np.mean(x)



def stat_susceptibility(x):
    mu = np.mean(x)

    if abs(mu) < 1e-12:
        return 0.0

    return np.var(x, ddof=1) #######/ mu

    
    # def stat_susceptibility(x):
#     # Mathematica: Variance[...] / Mean[...] where Variance uses ddof=1
#     return np.var(x, ddof=1) / np.mean(x)

# %%
def block_jackknife(data, stat_func, B):
    """
    Block jackknife with B blocks.
      - truncate data to m*B elements
      - reshape into B blocks of size m
      - compute full estimator EX on truncated data
      - leave one block out at a time, compute stat on remaining B-1 blocks
      - bias = (B-1) * (mean(dats) - EX)          [jack.pdf eq 3.2.1]
      - theta_jack = EX - bias                      [bias-corrected estimate]
      - var = Variance(dats) * (B-1)^2 / B         [Mathematica Variance = ddof=1]
      - se = sqrt(var)

    Returns: (theta_hat, theta_jack, se) for this specific B,
             or None if block size < 1.
    """
    n = len(data)
    m = n // B  # block size (integer division, matches Mathematica Quotient)

    if m < 1:
        return None

    # Truncate to m*B  (matches: data[[1 ;; Quotient[len,B]*B]])
    data = data[:m * B]

    # Reshape into B blocks  (matches: Table[data[[m*i+1 ;; m*(i+1)]], {i,0,B-1}])
    blocks = data.reshape(B, m)

    # Full estimator on truncated data  (matches: EX = stat_func(data))
    theta_hat = stat_func(data)

    # Leave-one-block-out replicates
    # Matches: rands = Table[DeleteCases[Range[B], i], {i, B}]
    #          dats  = Table[stat(Flatten[blocks[rands[i]]]), {i, B}]
    dats = np.array([
        stat_func(np.concatenate([blocks[:i], blocks[i+1:]]).ravel())
        for i in range(B)
    ])

    # Bias: (B-1) * (mean(dats) - EX)  [jack.pdf 3.2.1, Mathematica bias line]
    bias = (B - 1) * (np.mean(dats) - theta_hat)

    # Bias-corrected estimator: EXUn = EX - bias
    theta_jack = theta_hat - bias

    # Variance of replications using ddof=1  (Mathematica Variance = sample variance)
    # var = Variance[dats] * (B-1)^2 / B
    var = np.var(dats, ddof=1) * (B - 1)**2 / B
    se = np.sqrt(var)

    return theta_hat, theta_jack, se

# %%
# =============================================================================
# JACKKNIFE OVER Delta — returns FULL TABLE for every B, matching Mathematica output
# =============================================================================

def jackknife_over_Delta(P_B, Delta, stat_func, B_range=range(2, 101)):
    """
    For each unique Delta value, run block_jackknife for every B in B_range.

    Returns a dict:  {k: DataFrame with columns [B, theta_hat, theta_jack, se]}

    This matches the Mathematica Table[..., {ildanych, 2, 100, 1}] output exactly.
    You can then inspect SE vs B plots to find the plateau, rather than
    artificially picking the maximum SE.
    """
    df_input = pd.DataFrame({"Delta": Delta, "P_B": P_B})
    results = {}

    for d, group in df_input.groupby("Delta"):
        data = group["P_B"].values
        # print(k, len(data))

        if len(data) < 2:
            continue

        rows = []
        for B in B_range:
            out = block_jackknife(data, stat_func, B)
            if out is None:
                continue
            theta_hat, theta_jack, se = out
            rows.append({
                "B":          B,
                "theta_hat":  theta_hat,   # EX  in Mathematica
                "theta_jack": theta_jack,  # EXUn in Mathematica
                "se":         se,          # Smse in Mathematica
            })

        results[d] = pd.DataFrame(rows)
    return results

# %%
def summarise_jackknife(results_dict):

    Delta_vals, theta_arr, se_arr = [], [], []

    for d in sorted(results_dict.keys()):
        df = results_dict[d]

        if df.empty:
            continue

        df_valid = df.dropna(subset=["se"])

        if df_valid.empty:
            print(f"All SE are NaN for Delta={d}")
            continue

        row = df_valid.loc[df_valid["se"].idxmax()]

        Delta_vals.append(d)
        theta_arr.append(row["theta_jack"])
        se_arr.append(row["se"])

    return (
        np.array(Delta_vals),
        np.array(theta_arr),
        np.array(se_arr),
    )



def plot_se_vs_B(results_dict, stat_label, target_Deltas=None, ncols=5):
    """
    Plot SE vs B for each K value.
    Use this to verify that the SE has plateaued before trusting the summary.
    All K values are shown, arranged in a grid with ncols columns.
    """
    ds = sorted(results_dict.keys())
    if target_Deltas is not None:
        ds = [k for k in ds if k in target_Deltas]

    n = len(ds)
    if n == 0:
        return

    nrows = int(np.ceil(n / ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 3.5 * nrows), squeeze=False)

    for idx, k in enumerate(ds):
        row, col = divmod(idx, ncols)
        ax = axes[row][col]
        df = results_dict[k]
        ax.plot(df["B"], df["se"], lw=1.5)
        ax.set_title(f"Delta = {k:.3f}")
        ax.set_xlabel("B (number of blocks)")
        ax.set_ylabel(f"SE of {stat_label}")
        ax.grid(True, alpha=0.3)

    # Hide any leftover empty subplots
    for idx in range(n, nrows * ncols):
        row, col = divmod(idx, ncols)
        axes[row][col].set_visible(False)

    fig.suptitle(f"SE vs B — {stat_label} (should plateau)", y=1.02)
    plt.tight_layout()

# %%
from scipy.interpolate import interp1d
from scipy.optimize import brentq


def find_delta_crit(D, mean, mean_err):
    """
    Find delta where mean(delta)=0.5
    and estimate uncertainty via error propagation.
    """

    idx_close = np.argmin(np.abs(mean-0.5))
    d_close = D[idx_close]
    
    f = interp1d(
        D,
        mean - 0.5,
        kind="linear",
        bounds_error=False
    )

    idx = np.where(
        (mean[:-1] - 0.5) *
        (mean[1:]  - 0.5) <= 0
    )[0]

    if len(idx) == 0:
        return np.nan, np.nan, np.nan

    i = idx[0]

    dcrit = brentq(
        lambda x: f(x),
        D[i],
        D[i + 1]
    )

    slope = (
        mean[i + 1] - mean[i]
    ) / (
        D[i + 1] - D[i]
    )

    sigma_p = np.interp(
        dcrit,
        [D[i], D[i + 1]],
        [mean_err[i], mean_err[i + 1]]
    )
    if abs(slope) < 1e-12:
        return dcrit, np.nan, d_close
    
    sigma_d = sigma_p / abs(slope)

    return dcrit, sigma_d, d_close

# %%
def timed(func, *args, **kwargs):
    t0 = time.perf_counter()
    result = func(*args, **kwargs)
    elapsed = time.perf_counter() - t0
    return result, elapsed

# %%
# =============================================================================
# MAIN
# =============================================================================

neighbors = list(range(1, 52, 2)) + [61, 81, 101, 151, 201]

algorithms = [
    "auto",
    "kd_tree",
    "ball_tree",
    "brute",
]

models = {}

for algorithm in algorithms:
    for k in neighbors:
        name = f"KNN | {algorithm} | k={k}"

        models[name] = KNeighborsClassifier(
            n_neighbors=k,
            algorithm=algorithm,
            n_jobs=-1,
        )

curves = {}

for feature_name, cols in feature_sets.items():

    X_train_fs = X_train[:, cols]
    X_full_fs  = X_full[:, cols]

    curves[feature_name] = {}

    print(
        f"\n{'='*70}"
        f"\nFEATURE SET: {feature_name}"
        f" ({len(cols)} features)"
        f"\n{'='*70}"
    )

    for name, base_model in models.items():

        print(f"\n{'='*50}\nModel: {name}\n{'='*50}")
        curves[feature_name][name] = {}

        for calibrated in [False]:

            label = "calibrated" if calibrated else "uncalibrated"

            model = build_model(base_model, calibrated=calibrated)

            (train_score, P_B), model_time = timed(
                run_supervised_pipeline,
                model,
                X_train_fs,
                y_train,
                X_full_fs,
            )

            mean_results, mean_jack_time = timed(
                jackknife_over_Delta,
                P_B,
                Delta_full,
                stat_mean,
            )

            chi_results, chi_jack_time = timed(
                jackknife_over_Delta,
                P_B,
                Delta_full,
                stat_susceptibility,
            )

            print(f"  Delta values found: {len(mean_results)}")

            (D_mean, mean_jack, mean_se), summary_mean_time = timed(
                summarise_jackknife,
                mean_results,
            )

            (D_chi, chi_jack, chi_se), summary_chi_time = timed(
                summarise_jackknife,
                chi_results,
            )

            (dcrit, dcrit_err, d_close), time_delta_crit = timed(
                find_delta_crit,
                D_mean,
                mean_jack,
                mean_se,
            )

            total_time = (
                model_time
                + mean_jack_time
                + chi_jack_time
                + summary_mean_time
                + summary_chi_time
                + time_delta_crit
            )

            print(
                f"{label:12s} | "
                f"train_acc={train_score:.4f} | "
                f"total_time={total_time:.3f}"
            )

            curves[feature_name][name][label] = {
                "train_acc": train_score,
                "runtime_sec": total_time,
                "D": D_mean,
                "mean": mean_jack,
                "mean_se": mean_se,
                "chi": chi_jack,
                "chi_se": chi_se,
                "Delta_crit": dcrit,
                "Delta_crit_err": dcrit_err,
                "Delta_close": d_close,
                "_mean_results": mean_results,
                "_chi_results": chi_results,
            }

            summary_rows.append({
                "feature_set": feature_name,
                "n_features": len(cols),

                "model": "KNN",
                "algorithm": base_model.algorithm,
                "n_neighbors": base_model.n_neighbors,

                "calibration": label,
                "train_acc": train_score,

                "Delta_crit": dcrit,
                "Delta_crit_err": dcrit_err,
                "Delta_close": d_close,
                "N_Delta": len(D_mean),

                "runtime_model": round(model_time, 3),
                "runtime_jackknife_mean": round(mean_jack_time, 3),
                "runtime_jackknife_chi": round(chi_jack_time, 3),
                "summary_mean_time": round(summary_mean_time, 4),
                "summary_chi_time": round(summary_chi_time, 4),
                "runtime_delta_crit": round(time_delta_crit, 5),
                "runtime_total": round(total_time, 3),
            })

            for d, m, err in zip(D_mean, mean_jack, mean_se):
                mean_rows.append({
                    "feature_set": feature_name,
                    "n_features": len(cols),
                    "model": "KNN",
                    "algorithm": base_model.algorithm,
                    "n_neighbors": base_model.n_neighbors,
                    "calibration": label,
                    "Delta": d,
                    "mean": m,
                    "mean_err": err,
                })

            for d, c, err in zip(D_chi, chi_jack, chi_se):
                chi_rows.append({
                    "feature_set": feature_name,
                    "n_features": len(cols),
                    "model": "KNN",
                    "algorithm": base_model.algorithm,
                    "n_neighbors": base_model.n_neighbors,
                    "calibration": label,
                    "Delta": d,
                    "chi": c,
                    "chi_err": err,
                })
# Out:
# ======================================================================
# FEATURE SET: 20 (20 features)
# ======================================================================
#
# ==================================================
# Model: KNN | auto | k=1
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.996
#
# ==================================================
# Model: KNN | auto | k=3
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.651
#
# ==================================================
# Model: KNN | auto | k=5
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.128
#
# ==================================================
# Model: KNN | auto | k=7
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.373
#
# ==================================================
# Model: KNN | auto | k=9
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.017
#
# ==================================================
# Model: KNN | auto | k=11
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.076
#
# ==================================================
# Model: KNN | auto | k=13
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.615
#
# ==================================================
# Model: KNN | auto | k=15
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.754
#
# ==================================================
# Model: KNN | auto | k=17
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.551
#
# ==================================================
# Model: KNN | auto | k=19
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.331
#
# ==================================================
# Model: KNN | auto | k=21
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.149
#
# ==================================================
# Model: KNN | auto | k=23
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.862
#
# ==================================================
# Model: KNN | auto | k=25
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.502
#
# ==================================================
# Model: KNN | auto | k=27
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.115
#
# ==================================================
# Model: KNN | auto | k=29
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.026
#
# ==================================================
# Model: KNN | auto | k=31
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.159
#
# ==================================================
# Model: KNN | auto | k=33
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.176
#
# ==================================================
# Model: KNN | auto | k=35
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.382
#
# ==================================================
# Model: KNN | auto | k=37
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.634
#
# ==================================================
# Model: KNN | auto | k=39
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.424
#
# ==================================================
# Model: KNN | auto | k=41
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.037
#
# ==================================================
# Model: KNN | auto | k=43
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.082
#
# ==================================================
# Model: KNN | auto | k=45
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.939
#
# ==================================================
# Model: KNN | auto | k=47
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.180
#
# ==================================================
# Model: KNN | auto | k=49
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.828
#
# ==================================================
# Model: KNN | auto | k=51
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.176
#
# ==================================================
# Model: KNN | auto | k=61
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.128
#
# ==================================================
# Model: KNN | auto | k=81
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.792
#
# ==================================================
# Model: KNN | auto | k=101
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.887
#
# ==================================================
# Model: KNN | auto | k=151
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.668
#
# ==================================================
# Model: KNN | auto | k=201
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.307
#
# ==================================================
# Model: KNN | kd_tree | k=1
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=1.910
#
# ==================================================
# Model: KNN | kd_tree | k=3
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.118
#
# ==================================================
# Model: KNN | kd_tree | k=5
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.074
#
# ==================================================
# Model: KNN | kd_tree | k=7
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=1.972
#
# ==================================================
# Model: KNN | kd_tree | k=9
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.336
#
# ==================================================
# Model: KNN | kd_tree | k=11
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.247
#
# ==================================================
# Model: KNN | kd_tree | k=13
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.369
#
# ==================================================
# Model: KNN | kd_tree | k=15
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.340
#
# ==================================================
# Model: KNN | kd_tree | k=17
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.477
#
# ==================================================
# Model: KNN | kd_tree | k=19
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.183
#
# ==================================================
# Model: KNN | kd_tree | k=21
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.392
#
# ==================================================
# Model: KNN | kd_tree | k=23
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.315
#
# ==================================================
# Model: KNN | kd_tree | k=25
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.342
#
# ==================================================
# Model: KNN | kd_tree | k=27
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.431
#
# ==================================================
# Model: KNN | kd_tree | k=29
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.488
#
# ==================================================
# Model: KNN | kd_tree | k=31
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.498
#
# ==================================================
# Model: KNN | kd_tree | k=33
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.320
#
# ==================================================
# Model: KNN | kd_tree | k=35
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.423
#
# ==================================================
# Model: KNN | kd_tree | k=37
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.488
#
# ==================================================
# Model: KNN | kd_tree | k=39
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.526
#
# ==================================================
# Model: KNN | kd_tree | k=41
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.394
#
# ==================================================
# Model: KNN | kd_tree | k=43
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.565
#
# ==================================================
# Model: KNN | kd_tree | k=45
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.424
#
# ==================================================
# Model: KNN | kd_tree | k=47
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.433
#
# ==================================================
# Model: KNN | kd_tree | k=49
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.441
#
# ==================================================
# Model: KNN | kd_tree | k=51
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.366
#
# ==================================================
# Model: KNN | kd_tree | k=61
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.585
#
# ==================================================
# Model: KNN | kd_tree | k=81
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.457
#
# ==================================================
# Model: KNN | kd_tree | k=101
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.754
#
# ==================================================
# Model: KNN | kd_tree | k=151
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.922
#
# ==================================================
# Model: KNN | kd_tree | k=201
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.092
#
# ==================================================
# Model: KNN | ball_tree | k=1
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.437
#
# ==================================================
# Model: KNN | ball_tree | k=3
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.243
#
# ==================================================
# Model: KNN | ball_tree | k=5
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.489
#
# ==================================================
# Model: KNN | ball_tree | k=7
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.607
#
# ==================================================
# Model: KNN | ball_tree | k=9
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.749
#
# ==================================================
# Model: KNN | ball_tree | k=11
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.300
#
# ==================================================
# Model: KNN | ball_tree | k=13
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.031
#
# ==================================================
# Model: KNN | ball_tree | k=15
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.793
#
# ==================================================
# Model: KNN | ball_tree | k=17
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.773
#
# ==================================================
# Model: KNN | ball_tree | k=19
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.991
#
# ==================================================
# Model: KNN | ball_tree | k=21
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.966
#
# ==================================================
# Model: KNN | ball_tree | k=23
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.997
#
# ==================================================
# Model: KNN | ball_tree | k=25
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.303
#
# ==================================================
# Model: KNN | ball_tree | k=27
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.408
#
# ==================================================
# Model: KNN | ball_tree | k=29
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.307
#
# ==================================================
# Model: KNN | ball_tree | k=31
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.131
#
# ==================================================
# Model: KNN | ball_tree | k=33
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.410
#
# ==================================================
# Model: KNN | ball_tree | k=35
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.425
#
# ==================================================
# Model: KNN | ball_tree | k=37
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.445
#
# ==================================================
# Model: KNN | ball_tree | k=39
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=2.597
#
# ==================================================
# Model: KNN | ball_tree | k=41
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.350
#
# ==================================================
# Model: KNN | ball_tree | k=43
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.355
#
# ==================================================
# Model: KNN | ball_tree | k=45
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.171
#
# ==================================================
# Model: KNN | ball_tree | k=47
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.343
#
# ==================================================
# Model: KNN | ball_tree | k=49
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.533
#
# ==================================================
# Model: KNN | ball_tree | k=51
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.322
#
# ==================================================
# Model: KNN | ball_tree | k=61
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.695
#
# ==================================================
# Model: KNN | ball_tree | k=81
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.324
#
# ==================================================
# Model: KNN | ball_tree | k=101
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.763
#
# ==================================================
# Model: KNN | ball_tree | k=151
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.561
#
# ==================================================
# Model: KNN | ball_tree | k=201
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=3.924
#
# ==================================================
# Model: KNN | brute | k=1
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.129
#
# ==================================================
# Model: KNN | brute | k=3
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.687
#
# ==================================================
# Model: KNN | brute | k=5
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.193
#
# ==================================================
# Model: KNN | brute | k=7
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.280
#
# ==================================================
# Model: KNN | brute | k=9
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.041
#
# ==================================================
# Model: KNN | brute | k=11
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.019
#
# ==================================================
# Model: KNN | brute | k=13
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.325
#
# ==================================================
# Model: KNN | brute | k=15
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.324
#
# ==================================================
# Model: KNN | brute | k=17
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.449
#
# ==================================================
# Model: KNN | brute | k=19
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.170
#
# ==================================================
# Model: KNN | brute | k=21
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.094
#
# ==================================================
# Model: KNN | brute | k=23
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.370
#
# ==================================================
# Model: KNN | brute | k=25
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.832
#
# ==================================================
# Model: KNN | brute | k=27
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.615
#
# ==================================================
# Model: KNN | brute | k=29
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.089
#
# ==================================================
# Model: KNN | brute | k=31
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.555
#
# ==================================================
# Model: KNN | brute | k=33
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.343
#
# ==================================================
# Model: KNN | brute | k=35
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.506
#
# ==================================================
# Model: KNN | brute | k=37
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.808
#
# ==================================================
# Model: KNN | brute | k=39
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.083
#
# ==================================================
# Model: KNN | brute | k=41
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.224
#
# ==================================================
# Model: KNN | brute | k=43
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.319
#
# ==================================================
# Model: KNN | brute | k=45
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=11.982
#
# ==================================================
# Model: KNN | brute | k=47
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.564
#
# ==================================================
# Model: KNN | brute | k=49
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=13.364
#
# ==================================================
# Model: KNN | brute | k=51
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.175
#
# ==================================================
# Model: KNN | brute | k=61
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.216
#
# ==================================================
# Model: KNN | brute | k=81
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.406
#
# ==================================================
# Model: KNN | brute | k=101
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.192
#
# ==================================================
# Model: KNN | brute | k=151
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.463
#
# ==================================================
# Model: KNN | brute | k=201
# ==================================================
#   Delta values found: 12
# uncalibrated | train_acc=1.0000 | total_time=12.272

# %%
import os

os.makedirs("results", exist_ok=True)

pd.DataFrame(summary_rows).to_csv(
    "results/summaryKNN20.csv",
    index=False
)

pd.DataFrame(mean_rows).to_csv(
    "results/curve_meanKNN20.csv",
    index=False
)

pd.DataFrame(chi_rows).to_csv(
    "results/curve_chiKNN20.csv",
    index=False
)
