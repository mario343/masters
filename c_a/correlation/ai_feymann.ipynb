# %%
import aifeynman

aifeynman.run_aifeynman(
    "./",
    "f10.txt",
    60,
    "14ops.txt",
    polyfit_deg=3,
    NN_epochs=2000,
)
# Out:
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve ./f10.txt_train
# Rejection threshold.....    10.000
# Bit margin..............     0.000
# STOP DEATH ERROR: TOO MANY VARIABLES
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve ./f10.txt_train
# Rejection threshold.....    10.000
# Bit margin..............     0.000
# STOP DEATH ERROR: TOO MANY VARIABLES
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/f10.txt_train
# Rejection threshold.....    10.000
# Bit margin..............     0.000
# STOP DEATH ERROR: TOO MANY VARIABLES
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/f10.txt_train
# Rejection threshold.....    10.000
# ...
